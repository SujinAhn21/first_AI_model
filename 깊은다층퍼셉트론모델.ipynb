# %% [markdown]
# <a href="https://colab.research.google.com/github/SujinAhn21/Sujin-Ahn/blob/main/%EA%B9%8A%EC%9D%80%EB%8B%A4%EC%B8%B5%ED%8D%BC%EC%85%89%ED%8A%B8%EB%A1%A0%EB%AA%A8%EB%8D%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 0. 사용할  패키지  불러오기 
import numpy as np
from keras.models import Sequential 
from keras.layers import Dense 
import random

# %%
# 1. 데이터셋  생성하기
x_train = np.random.random((1000, 1))
y_train = x_train * 2 + np.random.random((1000, 1)) / 3.0   
x_test = np.random.random((100, 1))
y_test = x_test * 2 + np.random.random((100, 1)) / 3.0

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
import pandas as pd
x_train=pd.read_csv('x_train.csv', sep=",", header=None)
y_train=pd.read_csv('y_train.csv', sep=",", header=None)
x_test=pd.read_csv('x_test.csv', sep=",", header=None)
y_test=pd.read_csv('y_test.csv', sep=",", header=None)

# %%
x_train.describe()
# Out:
#                 0             1            2             3
# count  158.000000    158.000000   158.000000    158.000000
# mean   101.740506  74250.000000  1240.103481  12825.436264
# std      4.322360   2365.622688    35.298328   1203.671671
# min     94.790001  69300.000000  1172.700000  10646.099610
# 25%     98.065002  72737.500000  1216.730000  11761.340332
# 50%    102.070000  74920.000000  1233.025000  12787.729985
# 75%    105.387497  75857.500000  1274.675000  13770.157713
# max    109.050003  78360.000000  1314.740000  15832.799810

# %%
y_train.describe()
# Out:
#                   0
# count    158.000000
# mean   32925.615190
# std     9319.507289
# min    19262.900000
# 25%    23028.125000
# 50%    36580.900000
# 75%    41469.250000
# max    47449.000000

# %%
x_test.describe()
# Out:
#                 0             1            2             3
# count   54.000000     54.000000    54.000000     54.000000
# mean   110.622407  75681.666667  1155.128704  11018.304074
# std      2.100838    862.118387    22.334459    411.926447
# min    106.279999  74240.000000  1105.870000  10321.389650
# 25%    109.702497  75142.500000  1139.345000  10676.977300
# 50%    110.654999  75555.000000  1149.825000  11038.074710
# 75%    112.219999  75980.000000  1176.267500  11214.922852
# max    114.110001  77930.000000  1196.380000  11862.129880

# %%
y_test.describe()
# Out:
#                   0
# count     54.000000
# mean   19096.896296
# std     1348.703899
# min    15776.200000
# 25%    18915.025000
# 50%    19355.650000
# 75%    20115.250000
# max    21145.900000

# %%
# 2. 모델  구성하기
model = Sequential()
model.add(Dense(64, input_dim=4, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(1))

# %%
# 3. 모델  학습과정  설정하기
model.compile(optimizer='rmsprop', loss='mse')

# %%
# 4. 모델  학습시키기
hist = model.fit(x_train, y_train, epochs=50, batch_size=64)
# Out:
# Epoch 1/50
# 3/3 [==============================] - 0s 5ms/step - loss: 26689394.0000
# Epoch 2/50
# 3/3 [==============================] - 0s 5ms/step - loss: 29519486.0000
# Epoch 3/50
# 3/3 [==============================] - 0s 5ms/step - loss: 27304538.0000
# Epoch 4/50
# 3/3 [==============================] - 0s 5ms/step - loss: 30564456.0000
# Epoch 5/50
# 3/3 [==============================] - 0s 4ms/step - loss: 26962308.0000
# Epoch 6/50
# 3/3 [==============================] - 0s 5ms/step - loss: 29409592.0000
# Epoch 7/50
# 3/3 [==============================] - 0s 4ms/step - loss: 26402120.0000
# Epoch 8/50
# 3/3 [==============================] - 0s 6ms/step - loss: 27488188.0000
# Epoch 9/50
# 3/3 [==============================] - 0s 4ms/step - loss: 28365960.0000
# Epoch 10/50
# 3/3 [==============================] - 0s 5ms/step - loss: 28421132.0000
# Epoch 11/50
# 3/3 [==============================] - 0s 4ms/step - loss: 27522424.0000
# Epoch 12/50
# 3/3 [==============================] - 0s 5ms/step - loss: 28679592.0000
